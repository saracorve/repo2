# %%
import pandas as pd
datos  = {"nombre": ["Pedro", "Juan", "Lorena"], "edad" : [25, 39, 33]}
df = pd.DataFrame(datos)
df
# Out:
#    nombre  edad
# 0   Pedro    25
# 1    Juan    39
# 2  Lorena    33

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.nombre
# Out:
# 0     Pedro
# 1      Juan
# 2    Lorena
# Name: nombre, dtype: str
